# %%
import pandas as pd

# %%
#file source
#pd.read_parquet("./tmp/PAAC1901.parquet").head(100).to_csv("PAAC1901.csv",index=False)
df = pd.read_csv('sample/PAAC1901.csv')
df.head()
# Out:
#    PA_CODUNI  PA_GESTAO PA_CONDIC  PA_UFMUN  PA_REGCT  PA_INCOUT  PA_INCURG  \
# 0    7334710     120000        EP    120020         0          0          0
# 1    7334710     120000        EP    120020         0          0          0
# 2    7334710     120000        EP    120020         0          0          0
# 3    7334710     120000        EP    120020         0          0          0
# 4    7334710     120000        EP    120020         0          0          0
#
#    PA_TPUPS  PA_TIPPRE PA_MN_IND  ...  PA_CODOCO  PA_FLQT  PA_FLER  PA_ETNIA  \
# 0        43          0         M  ...          1        K        0
# 1        43          0         M  ...          1        K        0
# 2        43          0         M  ...          1        K        0
# 3        43          0         M  ...          1        K        0
# 4        43          0         M  ...          1        K        0
#
#    PA_VL_CF  PA_VL_CL  PA_VL_INC  PA_SRV_C      PA_INE PA_NAT_JUR
# ...

# %%
df.info(max_cols=100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 60 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PA_CODUNI   100 non-null    int64
#  1   PA_GESTAO   100 non-null    int64
#  2   PA_CONDIC   100 non-null    object
#  3   PA_UFMUN    100 non-null    int64
#  4   PA_REGCT    100 non-null    int64
#  5   PA_INCOUT   100 non-null    int64
#  6   PA_INCURG   100 non-null    int64
#  7   PA_TPUPS    100 non-null    int64
#  8   PA_TIPPRE   100 non-null    int64
#  9   PA_MN_IND   100 non-null    object
#  10  PA_CNPJCPF  100 non-null    int64
#  11  PA_CNPJMNT  100 non-null    int64
#  12  PA_CNPJ_CC  100 non-null    int64
#  13  PA_MVM      100 non-null    int64
#  14  PA_CMP      100 non-null    int64
#  15  PA_PROC_ID  100 non-null    int64
#  16  PA_TPFIN    100 non-null    int64
#  17  PA_SUBFIN   100 non-null    int64
#  18  PA_NIVCPL   100 non-null    int64
# ...

# %%
df.describe().T
# Out:
#             count          mean           std           min           25%  \
# PA_CODUNI   100.0  4.656688e+06  2.656047e+06  2.000024e+06  2.001586e+06
# PA_GESTAO   100.0  1.200008e+05  5.628212e+00  1.200000e+05  1.200000e+05
# PA_UFMUN    100.0  1.200368e+05  8.404400e+00  1.200100e+05  1.200400e+05
# PA_REGCT    100.0  2.845900e+02  1.401224e+03  0.000000e+00  0.000000e+00
# PA_INCOUT   100.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PA_INCURG   100.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PA_TPUPS    100.0  3.006000e+01  2.244581e+01  2.000000e+00  5.000000e+00
# PA_TIPPRE   100.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PA_CNPJCPF  100.0  2.062033e+13  2.362069e+13  4.034526e+12  4.034526e+12
# PA_CNPJMNT  100.0  1.936574e+12  2.025804e+12  0.000000e+00  0.000000e+00
# PA_CNPJ_CC  100.0  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# PA_MVM      100.0  2.019010e+05  0.000000e+00  2.019010e+05  2.019010e+05
# ...
